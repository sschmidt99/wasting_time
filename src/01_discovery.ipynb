# %%
import pandas as pd  
import numpy as np 
wasting_time = pd.read_csv("../data/raw/timewaster.csv", index_col=0)

# %%
#wasting_time.head()
# Out:
#         Age  Gender       Location  Income   Debt  Owns Property  \
# UserID
# 1        56    Male       Pakistan   82812   True           True
# 2        46  Female         Mexico   27999  False           True
# 3        32  Female  United States   42436  False           True
# 4        60    Male         Barzil   62963   True          False
# 5        25    Male       Pakistan   22096  False           True
#
#            Profession Demographics   Platform  Total Time Spent  ...  \
# UserID                                                           ...
# 1            Engineer        Rural  Instagram                80  ...
# 2              Artist        Urban  Instagram               228  ...
# 3            Engineer        Rural   Facebook                30  ...
# 4       Waiting staff        Rural    YouTube               101  ...
# 5             Manager        Urban     TikTok               136  ...
#
#         ProductivityLoss  Satisfaction     Watch Reason  DeviceType       OS  \
# ...

# %%
wasting_time.Platform
# Out:
# UserID
# 1       Instagram
# 2       Instagram
#           ...
# 999       YouTube
# 1000      YouTube
# Name: Platform, Length: 1000, dtype: object

# %%
wasting_time.loc[:, ['Platform', 'Gender', 'Total Time Spent']]
# Out:
#          Platform  Gender  Total Time Spent
# UserID
# 1       Instagram    Male                80
# 2       Instagram  Female               228
# ...           ...     ...               ...
# 999       YouTube    Male               151
# 1000      YouTube    Male               167
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## Sources:
#
# [Project Reboot](https://www.projectreboot.school/about)
